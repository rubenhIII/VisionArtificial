# %% [markdown]
# # Código de introducción Visión Artificial

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
import cv2

ruta_imagen = "img/lena.jpeg"
img = cv2.imread(ruta_imagen)

if img is not None:
    print(f'Estructura de la imagen {img.shape}')
    cv2.imshow("Imagen Lena", img)
    cv2.waitKey(0)
# Out:
# Estructura de la imagen (225, 225, 3)
# ...
# QFontDatabase: Cannot find font directory /home/ruben/Documentos/Codigos/Python/VisionArtificial/VisionArtificial/venv/lib/python3.11/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ruben/Documentos/Codigos/Python/VisionArtificial/VisionArtificial/venv/lib/python3.11/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ruben/Documentos/Codigos/Python/VisionArtificial/VisionArtificial/venv/lib/python3.11/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# ...
